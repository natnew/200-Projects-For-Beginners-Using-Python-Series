# %% [markdown]
# <a href="https://colab.research.google.com/github/natnew/200-Projects-For-Beginners-Using-Python-Series/blob/main/Python_Automation_TED_Talk_Downloader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TED Talk Downloader

# %% [markdown]
# ## Set Up The Environment

# %%
#!pip install requests
#install Request
#!pip install beautifulsoup4
#from bs4 import BeautifulSoup
#import re #Regular Expression pattern matching
import json #json processing

# %% [markdown]
# ## Project

# %%
#Save the URL
url = 'https://www.ted.com/talks/malcolm_gladwell_choice_happiness_and_spaghetti_sauce/'

# %%
#Get the URL
r = requests.get(url)

print("Download about to start")
# Out:
# Download about to start

# %%
#get the content from the URL
r.content
# Out:
# b'<!DOCTYPE html><html><head><script src="https://cdn.cookielaw.org/consent/eb3a3101-85ef-45e5-a75f-dbd35e8d0b4d/OtAutoBlock.js"></script><script src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" charSet="UTF-8" data-domain-script="eb3a3101-85ef-45e5-a75f-dbd35e8d0b4d"></script><script>function OptanonWrapper() {\n  const categoriesConsentedTo = window.OnetrustActiveGroups;\n  /* eslint-reason The underscores help keep this name unique and make the\n   * variable name ugly, to dissuade users from referencing it unless absolutely\n   * necessary (similar to React\'s dangerouslySetInnerHTML.__html prop) */\n\n  /* eslint-disable-next-line no-underscore-dangle */\n\n  window.__userHasConsentedToTargetingCookies = window.OnetrustActiveGroups.includes(\'C0004\');\n  const activeGroupsLoaded = new Event(\'OnetrustActiveGroupsLoaded\');\n  window.dispatchEvent(activeGroupsLoaded);\n  window.OneTrust.OnConsentChanged(() => {\n    if (categoriesConsentedTo === window.OnetrustActive
# ...

# %%
#Get the status
r.status_code
# Out:
# 200

# %%
#Save the content of the URL to soup
soup = BeautifulSoup(r.content, "html.parser")

# %% [markdown]
# We can visit the page here: https://www.ted.com/talks/malcolm_gladwell_choice_happiness_and_spaghetti_sauce/ and inspect the page for particular information.

# %%
#Get specific content using an id
next_data_script = soup.find(id="__NEXT_DATA__")

# %%
next_data_script
# Out:
# <script id="__NEXT_DATA__" type="application/json">{"props":{"pageProps":{"action":null,"videoData":{"__typename":"Video","id":"20","slug":"malcolm_gladwell_choice_happiness_and_spaghetti_sauce","title":"Choice, happiness and spaghetti sauce","socialTitle":"Choice, happiness and spaghetti sauce","presenterDisplayName":"Malcolm Gladwell","internalLanguageCode":"en","recordedOn":"2004-02-26","curatorApproved":true,"viewedCount":9298913,"duration":1036,"publishedAt":"2006-09-19T00:11:00Z","topics":{"__typename":"TopicConnection","nodes":[{"__typename":"Topic","id":"4","name":"culture","slug":"culture"},{"__typename":"Topic","id":"18","name":"business","slug":"business"},{"__typename":"Topic","id":"21","name":"economics","slug":"economics"},{"__typename":"Topic","id":"39","name":"media","slug":"media"},{"__typename":"Topic","id":"58","name":"food","slug":"food"},{"__typename":"Topic","id":"83","name":"consumerism","slug":"consumerism"},{"__typename":"Topic","id":"84","name":"marketing","
# ...

# %%
data_json = next_data_script.string

# %%
data_json
# Out:
# '{"props":{"pageProps":{"action":null,"videoData":{"__typename":"Video","id":"20","slug":"malcolm_gladwell_choice_happiness_and_spaghetti_sauce","title":"Choice, happiness and spaghetti sauce","socialTitle":"Choice, happiness and spaghetti sauce","presenterDisplayName":"Malcolm Gladwell","internalLanguageCode":"en","recordedOn":"2004-02-26","curatorApproved":true,"viewedCount":9298913,"duration":1036,"publishedAt":"2006-09-19T00:11:00Z","topics":{"__typename":"TopicConnection","nodes":[{"__typename":"Topic","id":"4","name":"culture","slug":"culture"},{"__typename":"Topic","id":"18","name":"business","slug":"business"},{"__typename":"Topic","id":"21","name":"economics","slug":"economics"},{"__typename":"Topic","id":"39","name":"media","slug":"media"},{"__typename":"Topic","id":"58","name":"food","slug":"food"},{"__typename":"Topic","id":"83","name":"consumerism","slug":"consumerism"},{"__typename":"Topic","id":"84","name":"marketing","slug":"marketing"},{"__typename":"Topic","id":"85"
# ...

# %%
player_data = json.loads(data_json)['props']['pageProps']['videoData']['playerData']

# %%
player_data
# Out:
# '{"id":"20","mediaIdentifier":"consus-pm1976-im2346","mediaProjectVersionIdentifier":"consus-pm1976-im2346","duration":1050,"languages":[{"languageName":"Greek","endonym":"Ελληνικά","languageCode":"el","ianaCode":"el","isRtl":false},{"languageName":"English","endonym":"English","languageCode":"en","ianaCode":"en","isRtl":false},{"languageName":"Vietnamese","endonym":"Tiếng Việt","languageCode":"vi","ianaCode":"vi","isRtl":false},{"languageName":"Italian","endonym":"Italiano","languageCode":"it","ianaCode":"it","isRtl":false},{"languageName":"Arabic","endonym":"العربية","languageCode":"ar","ianaCode":"ar","isRtl":true},{"languageName":"Portuguese, Brazilian","endonym":"Português brasileiro","languageCode":"pt-br","ianaCode":"pt-BR","isRtl":false},{"languageName":"Czech","endonym":"Čeština","languageCode":"cs","ianaCode":"cs","isRtl":false},{"languageName":"Indonesian","endonym":"Bahasa Indonesia","languageCode":"id","ianaCode":"id","isRtl":false},{"languageName":"Spanish","endonym":"E
# ...

# %%
url_content = json.loads(player_data)['resources']['h264'][0]['file']

# %%
#url_content[0]['file']
#mp4_url = json.loads(player_data)['resources']['h264'][0]['file']

# %%
url_content
# Out:
# 'https://py.tedcdn.com/consus/projects/00/19/74/006/products/2004-malcolm-gladwell-006-fallback-bbecfb71020ab7a780b94f6716837372-1200k.mp4'

# %%
#Get the content of the MP4 file
mp4_response = requests.get(url_content)

# %%
mp4_response.status_code
# Out:
# 200

# %%
file_name = 'ted_talk_video.mp4'

# %%
#Write the content of the MP4 file to the output file
with open(file_name,'wb') as f:
  f.write(mp4_response.content)
